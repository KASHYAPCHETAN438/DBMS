# %% [markdown]
# # 📘 SQL Complete Notes
# ## What is SQL?
#
# - SQL (Structured Query Language) is a standard language used to manage, manipulate, and query data stored in a relational database.
#
# ##🧩 Features of SQL
#
# - Easy to learn and use
#
# - Supports data definition, manipulation, and control
#
# - Can handle large amounts of data
#
# - Supports complex queries and joins
#
# - Portable and standardized
#
#
# <br>
# <br>

# %% [markdown]
# # 🧩 SQL Commands
#
# - SQL commands are instructions used to communicate with a database.
# - They help you create, retrieve, update, and manage data in a relational database.
#
# <br>
#
# ## 🔹 Types of SQL Commands
#
# | Category                               | What it does (Mardon-style)                  | Example Commands                                |
# | -------------------------------------- | ------------------------------------------- | ----------------------------------------------- |
# | **DDL (Data Definition Language)**     | Defines or changes **database structure**  | `CREATE`, `ALTER`, `DROP`, `TRUNCATE`, `RENAME` |
# | **DML (Data Manipulation Language)**   | Play with the **data inside tables**       | `INSERT`, `UPDATE`, `DELETE`                    |
# | **DQL (Data Query Language)**          | **Fetch data** from tables                 | `SELECT`                                        |
# | **DCL (Data Control Language)**        | **Manage who can do what**                 | `GRANT`, `REVOKE`                               |
# | **TCL (Transaction Control Language)** | **Control transactions** like a boss       | `COMMIT`, `ROLLBACK`, `SAVEPOINT`               |
#
# <br>
# <br>
#
# ## **💡 Tip:**
#
# - DDL → Structure changes
#
# - DML → Data changes (Manipulation)
#
# - DQL → Data fetch
#
# - DCL → Access control
#
# - TCL → Transaction management

# %% [markdown]
# # 1. **📘 What is DDL?**
#
# - DDL (Data Definition Language) is used to define, modify, and manage the structure of database objects — like tables, schemas, and indexes.
#
# -  DDL commands affect the structure of the database, not the data inside it.
# - All DDL commands are auto-committed — meaning once executed, the changes cannot be rolled back.

# %% [markdown]
# ## SQL Keywords for Database Definition (DDL)
#
# | Keyword             | Description                                                        |
# | ------------------- | ------------------------------------------------------------------ |
# | `CREATE`            | Creates a new database, table, view, or index                      |
# | `ALTER`             | Modifies an existing database object (add, remove, rename columns) |
# | `DROP`              | Deletes an object (table, database, index, view)                   |
# | `TRUNCATE`          | Removes all records from a table but keeps structure               |
# | `RENAME`            | Renames a table or column                                          |
# | `USE`               | Selects a database to work with                                    |
# | `SHOW`              | Displays information about databases, tables, columns, etc.        |
# | `DESCRIBE` / `DESC` | Displays structure of a table                                      |
#
#
# <br>

# %% [markdown]
# ---
#
# ## 🔹 **How to Create,View and Use database**
# - Use the **CREATE DATABASE** command to make a new database.
# - Use the **Show** to see all databases present in your SQL server.
# - To start working with a particular database, use the **USE command**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
#
# ## 🔹 **How to Create Table and View structure or schema**
#
# - Use the **CREATE TABLE** command to make a new table inside a database.
#
#    ### Ex :
#
#       Create table table_name(
#
#        -- define column here
#
#        )
#
# - Use the **DESCRIBE/DESC** command  to see the structure of the table.
#
#   ### Ex :
#       Desc table_name;
#           OR
#       Describe table_name;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
#
# ## 🔹 **How View list of Table inside Database**
#
# - Use the **SHOW TABLES** command to list all tables present in the selected database.
#
#    ### Ex :
#
#       Show tables;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
#
# ## 🔹 **How Rename of a Table**
# - To change name of  table’s Use the **RENAME TABLE** command.
#
#    ### Ex :
#
#       Rename Table old_name To New_name;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
#
# ## 🔹 How To  ALTER TABLE
#
# - Use ALTER TABLE to modify table structure without losing data.
#
# ###You can
# - Add : Use Add Column to add new column in table.
# - Modify : change data type, size, or attributes of an existing column.
# - Drop Columns : Use DROP Columns to delete the columns completely.

# %% [markdown]
# ### i) ADD New Column
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## ii) Modify Column
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## iii) Drop Column
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#  ---
#  ## 🔹 How to work TRUNCATE Command
#
# - Used to delete all records from a table but keep the table structure intact.
# - means we can see table schema by using desc.
#
# ### Syntax :
#     TRUNCATE TABLE table_name;

# %% [markdown]
# ### Before Truncate the table have some records
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### After Truncate
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ----
#
#  ## 🔹 How to work Drop Command
#
#  - Used to delete databases, tables, or other objects permanently.
#  - Delete table schema as well as.
#
#          -- Drop table
#         DROP TABLE table_name;
#
#         -- Drop database
#         DROP DATABASE Database_name;
#
# ### Drop student_info  (Table)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Drop Sql_practices (Database)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 2. 📘 What is DML?
#
# - DML (Data Manipulation Language) is used to insert, update, delete, and retrieve data stored in database tables.
# - These commands work inside tables — they manipulate data, not structure.
# - DML commands can be rolled back using transactions (ROLLBACK, COMMIT).
# - They affect rows (records) inside a table.

# %% [markdown]
# ## SQL Keywords for Data Manipulation (DML)
#
# | Keyword  | Description                             |
# | -------- | --------------------------------------- |
# | `INSERT` | Adds new rows into a table              |
# | `UPDATE` | Modifies existing rows                  |
# | `DELETE` | Removes rows from a table               |
# | `VALUES` | Specifies values for `INSERT`           |
# | `SET`    | Used with `UPDATE` to assign new values |
#
#
# <br>
# <br>

# %% [markdown]
# ## i). INSERT
#
# - Adds new records (rows) into a table.
#
# <br>
#
# ### Syntax :
#
#     INSERT INTO table_name (column1, column2, ...)
#     VALUES (value1, value2, ...);
#
# <br>
#
# ### Example :
#
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# ## ii). UPDATE
#
# - Changes existing data in the table.
#
# - Always use a WHERE clause to avoid updating everything!
#
#
# ### Syntax :
#
#     UPDATE table_name
#     SET column1 = value1, column2 = value2, ...
#     WHERE condition;
#
# <br>
#
# ### Example :
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <br>
# <br>
#
# ## iii). SELECT
# - Used to retrieve data from one or more tables.
#
# - You can fetch specific columns, all columns, or apply filters, sorting, and conditions.
#
# ### Syntax :
#     -- Select all columns
#     SELECT * FROM table_name;
#
#     -- Select specific columns
#     SELECT column1, column2 FROM table_name;
#
#     -- Select with condition
#     SELECT * FROM table_name WHERE condition;
#
#
#
#
# <br>
#
# ### Example :
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <br>
# <br>
#
# ## iv). DELETE
# - The DELETE command is used to remove records (rows) from a table.
#
# - It does not delete the table structure, only the data inside it.
#
# - You can delete a specific row or all rows depending on the condition.
#
# ### Syntax :
#     -- Delete only specific records
#     DELETE FROM table_name
#     WHERE condition;
#
#     -- Delete entire data
#     DELETE FROM TABLE_NAME;
#
# <br>
#
# ### Example :
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 📘 What is DQL?
#
# - DQL (Data Query Language) is used to retrieve data from a database.
# - It helps users query, filter, sort, and analyze information stored in tables.
#
# - DQL mainly revolves around one powerful command: SELECT
# - It does not modify data, only reads it.
# - It can work with one or more tables at once.

# %% [markdown]
# ## SQL Keywords for Data Query (DQL)
#
# | Keyword    | Description                           |
# | ---------- | ------------------------------------- |
# | `SELECT`   | Fetches data from one or more tables  |
# | `FROM`     | Specifies table name(s)               |
# | `WHERE`    | Filters records based on condition    |
# | `ORDER BY` | Sorts the result set (ASC or DESC)    |
# | `GROUP BY` | Groups rows based on column values    |
# | `HAVING`   | Filters groups (used with GROUP BY)   |
# | `DISTINCT` | Removes duplicate rows                |
# | `LIMIT`    | Restricts number of rows returned     |
# | `AS`       | Renames a column or table (alias)     |

# %% [markdown]
# ## 🔹  SELECT Entire records
#
#
# ### Syntax :
#     SELECT * FROM table_name;
#
#
#
#
#
#
# ### Example :
#
#
# ![image.png](data:image/png;base64,...)
#
#
# <br>
# <br>

# %% [markdown]
# ## 🔹  SELECT specific columns
#
# ### Syntax :
#     SELECT Column1, Column2 ... FROM table_name;
#
#
#
#
#
# ### Example :
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <br>
#
# ## 🔹  WHERE (Filter records)
#
# ### Syntax :
#     SELECT * FROM table_name
#     WHERE Condition;
#
#
#
#
#
# ### Example :
#
# ![image.png](data:image/png;base64,...)
#
# <br>
# <br>

# %% [markdown]
# ## 🔹  ORDER BY (Sorting)
#
# ### Syntax :
#     SELECT * FROM table_name
#     ORDER BY Column_name DESC OR ASC;
#
#
#
# ### Example :
#
# ![image.png](data:image/png;base64,...)
#
# <br>
# <br>

# %% [markdown]
# ## 🔹  DISTINCT (Remove duplicates)
#
# ### Syntax :
#     SELECT DISTINCT Column_name FROM Table_name;
#
#
# ### Example :
#
# ![image.png](data:image/png;base64,...)
#
#
# <br>
# <br>

# %% [markdown]
# ## Summary Table
#
#
# | Keyword                     | Meaning                                      | Example                                    |
# | --------------------------- | -------------------------------------------- | ------------------------------------------ |
# | `DISTINCT`                  | Removes duplicate rows                       | `SELECT DISTINCT Name FROM Students;`      |
# | `DISTINCT *`                | Removes only fully identical rows            | `SELECT DISTINCT * FROM Students;`         |
# | `DISTINCT column1, column2` | Removes duplicates based on selected columns | `SELECT DISTINCT Name, Age FROM Students;` |
#
# <br>
# <br>

# %% [markdown]
# ## 🔹  GROUP BY (Grouping)
#
# ### Syntax :
#     SELECT Column_name, COUNT(*) AS Alis_name
#     FROM Table_name
#     GROUP BY Column_name;
#
#
# ### Example :
#
# ![image.png](data:image/png;base64,...)
#
# <br>
# <br>

# %% [markdown]
# ## 🔹 HAVING (Filter groups)
#
# ### Syntax :
#
#     SELECT Column_name, COUNT(*) AS Alis_name
#     FROM Table_name
#     GROUP BY Column_name
#     HAVING COUNT(*) > 1;
#
#
#
#
# ### Example :
#
# ![image.png](data:image/png;base64,...)
#
# <br>
# <br>

# %% [markdown]
# ## 🔹  LIMIT (Restrict output)
#
# ### Syntax :
#
#     SELECT * FROM table_name
#     LIMIT 3;
#
#
#
#
#
#
# ### Example :
#
# ![image.png](data:image/png;base64,...)
#
# <br>
# <br>

# %% [markdown]
# ##🔹  AS (Alias)
#
# ### Syntax :
#     SELECT Name AS Student_Name, City AS Location
#     FROM Students;
#
#
# ### Example :
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 🏗️ System Databases in MySQL (Default ones)
#
#
# | Database               | Purpose                                                                        |
# | ---------------------- | ------------------------------------------------------------------------------ |
# | **mysql**              | Stores user accounts, privileges, roles, and system tables for authentication. |
# | **information_schema** | Contains metadata about all databases, tables, columns, and constraints.       |
# | **performance_schema** | Used for monitoring MySQL performance (execution times, resource usage, etc.). |
# | **sys**                | Provides easy-to-read views for performance and diagnostics.                   |
#
#
# <br>
#
#
# ---
#
# <br>
#
# # 🧑‍💻 User in Mysql
#
# ## 🔹 Mysql Database
# - The user table inside the mysql database is a system table that stores all MySQL user accounts and their privileges.
#
# 🧩 Key Points:
#
# - It contains login details (username, host, password) and permissions for every MySQL user.
#
# - It decides who can connect, from where, and what actions they can perform.
#
# - It is part of the internal system database mysql, created automatically when MySQL is installe
#
#
#
# <br>
#
#
# ### Syntax :
#
#
#      -- View all details (User name, Host Type ,previleges)
#      USE mysql;
#      show tables;
#      SELECT * FROM user;
#
#                         OR
#
#      -- View only User name and Host Type
#      SELECT User, Host FROM mysql.user;
#
# <br>
#
# ### Example :
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <br>
#
# ## 1. Create a local user
#
#
# ### Syntax :
#
#      CREATE USER 'username'@'host' IDENTIFIED BY 'password';
#
# <br>
#
# ### **Explanation of Each Part:**
#
# | Part                           | Meaning                                                                                     |
# | ------------------------------ | ------------------------------------------------------------------------------------------- |
# | **`CREATE USER`**              | This command tells MySQL that you are creating a new user.                                  |
# | **`'username'`**               | The name of the new MySQL user you want to create (e.g., `'mohit'`).                        |
# | **`'host'`**                   | Specifies **from where the user can connect** (like `'localhost'`, `'%'`, `'192.168.1.5'`). |
# | **`IDENTIFIED BY 'password'`** | Sets the **login password** for the user (it’s stored in encrypted form).                   |
#
#
#
# <br>
#
# ### Example :
#
#
# ![image.png](data:image/png;base64,...)
#
#
#
# <br>
# <br>

# %% [markdown]
# <br>
#
# ## 2. Create a user that can connect from any host
#
# ### Syntax :
#
#      CREATE USER 'User_name'@'%' IDENTIFIED BY 'password';
#
#
# <br>
#
# ### Example :
#
# ![image.png](data:image/png;base64,...)
#
# <br>
# <br>

# %% [markdown]
# <br>
#
# ## 3. Create a user allowed from a specific IP
#
# ### Syntax :
#
#      CREATE USER 'User_name'@'192.168.1.100' IDENTIFIED BY 'password';
#
#
#
# <br>
#
# ### Example :
#
# ![image.png](data:image/png;base64,...)
#
#
# <br>
# <br>

# %% [markdown]
# ## 👉When ever we create user By default, MySQL automatically gives Previliges
#
# - GRANT USAGE ON `*.*` TO `mohit`@`localhost`
#
# ### This means:
#
# - Mohit can connect to MySQL (after entering password).
#
# - But Mohit cannot SELECT, INSERT, UPDATE, or DELETE any data.
#
# - Basically, a valid user account but with no data access

# %% [markdown]
# # 📘 What is DCL ?
#
# - DCL stands for Data Control Language
# - DCL commands in SQL are used to control access or permissions to the database objects like tables, views, and schemas.
# - They help in managing user privileges and security within the database.

# %% [markdown]
# ## SQL Keywords for Data Control (DCL)
#
# | Command    | Description                                                | Syntax                                                 | Example                                      |
# | ---------- | ---------------------------------------------------------- | ------------------------------------------------------ | -------------------------------------------- |
# | **GRANT**  | Gives specific privileges (permissions) to users or roles. | `GRANT privilege_name ON object_name TO user_name;`    | `GRANT SELECT, INSERT ON Students TO Mohit;` |
# | **REVOKE** | Removes (takes back) privileges given to users.            | `REVOKE privilege_name ON object_name FROM user_name;` | `REVOKE INSERT ON Students FROM Mohit;`      |

# %% [markdown]
# <br>
#
# ## 🔐 Privileges (Permissions)
#
# | Privilege          | Description                                  |
# | ------------------ | -------------------------------------------- |
# | **SELECT**         | User can retrieve (read) data from a table.  |
# | **INSERT**         | User can insert new records into a table.    |
# | **UPDATE**         | User can modify existing data.               |
# | **DELETE**         | User can remove data from a table.           |
# | **ALL PRIVILEGES** | Grants all possible permissions.             |
# | **REFERENCES**     | User can create foreign key references.      |
# | **ALTER**          | User can change table structure.             |
# | **INDEX**          | User can create or remove indexes.           |
# | **EXECUTE**        | User can run stored procedures or functions. |
#
#
# <br>
# <br>

# %% [markdown]
# # ------------- GRANT COMMAND -------------
#
# ## 1. GRANT Command (To Give single Permission)
#
# ### Syntax :
#
#     GRANT privilege_name
#     ON object_name
#     TO user_name;
#
#             OR
#
#     GRANT privilege_name
#     ON database_name.table_name
#     TO user_name;
#
# ### Example :
#
#     GRANT SELECT ON sql_practices.Students TO 'mohit'@'localhost';
#
#
#
# ![image.png](data:image/png;base64,...)
#
#
#
#
#
# <br>
# <br>

# %% [markdown]
# ## 2. Grant Command (Multiple privileges)
#
#
# ### Syntax :
#     GRANT SELECT, INSERT, UPDATE ON table_name TO user_name;
#
#                         OR
#
#     GRANT SELECT, INSERT, UPDATE ON database_name.table_name TO user_name;
#
#
#
# ### Example :
#
#
#
# <br>
# <br>

# %% [markdown]
# ## 3. Grant to multiple users
#
#
# ### Syntax :
#     GRANT SELECT, INSERT, UPDATE ON table_name TO user1,user2;
#
# ### Example :
#
#
#
# <br>
# <br>

# %% [markdown]
# ## 4. Grant all privileges
#
# ### Syntax :
#     GRANT ALL PRIVILEGES ON table_name TO user_name;
#
#                         OR
#
#     GRANT ALL PRIVILEGES ON database_name.table_name TO user_name;
#
#
#
# ### Example :
#
#
# <br>
# <br>

# %% [markdown]
# # --------------- REVOKE COMMAND -----------------
#
# ## 1. Revoke Command (To Remove Permission)
#
# ### Syntax :
#     REVOKE privilege_name
#     ON object_name
#     FROM user_name;
#
#
#
# ### Example :
#
#
# <br>
# <br>

# %% [markdown]
# ## 2. Revoke multiple privileges
#
#
# ### Syntax :
#
#
# ### Example :
#
# <br>
# <br>

# %% [markdown]
# ## 3. Revoke all privileges
#
# ### Syntax :
#
#
# ### Example :
#
# <br>
# <br>

# %% [markdown]
# # 📘 What is TCL ?
#  - TCL stands for Transaction Control Language
#
# - TCL commands in SQL are used to manage transactions in a database.
# - A transaction is a group of one or more SQL operations (like INSERT, UPDATE, DELETE) that are executed as a single unit of work.
#
# - TCL ensures data integrity and allows you to commit or rollback changes made during a transaction

# %% [markdown]
# ##  SQL Keywords for Transaction Control (TCL)
#
# | Keyword       | Description                                |
# | ------------- | ------------------------------------------ |
# | `COMMIT`      | Saves all changes permanently              |
# | `ROLLBACK`    | Undo changes since last COMMIT             |
# | `SAVEPOINT`   | Creates a save point to rollback partially |
# | `TRANSACTION` | Starts a new transaction                   |
# | `BEGIN`       | Marks beginning of a transaction           |
# | `END`         | Marks end of a transaction                 |
