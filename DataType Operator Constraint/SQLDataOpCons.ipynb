# %% [markdown]
# ## Data Types in SQL
#
# ### 1. Numeric data type
#
# | Data Type                        | Description                                                          | Example             |
# | -------------------------------- | -------------------------------------------------------------------- | ------------------- |
# | `INT` / `INTEGER`                | Whole numbers (no decimals upto 10 digit)                                          | 10                  |
# | `SMALLINT`                       | Small-range integers(-32768 to 32767)                                                 | 120                 |
# | `BIGINT`                         | Very large integers                                                  | 9223372036854775807 |
# | `TINYINT`                        | Very small integers (0 to 255)                                       | 100                 |
# | `DECIMAL(p,s)` or `NUMERIC(p,s)` | Fixed precision numbers (p = total digits, s = digits after decimal) | 123.45              |
# | `FLOAT`                          | Approximate decimal numbers (single precision)                       | 12.34               |
# | `DOUBLE` / `REAL`                | Approximate decimal numbers (double precision)                       | 12345.6789          |
# | `BIT`                            | Boolean type (0 or 1)                                                | 1                   |
#
#
# <br>
#
# ### Syantax :
#       CREATE TABLE products (
#       product_id INT,
#       price DECIMAL(10,2),
#       rating FLOAT
#       );

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# <br><br>

# %% [markdown]
# ## 2. Character / String Data Types
#
# | Data Type     | Description                                            | Example                       |
# | ------------- | ------------------------------------------------------ | ----------------------------- |
# | `CHAR(n)`     | Fixed-length string (n characters)                     | 'DELHI'                       |
# | `VARCHAR(n)`  | Variable-length string (up to n characters)            | 'Mohit Kashyap'               |
# | `TEXT`        | Large text block                                       | 'This is a long paragraph...' |
# | `NVARCHAR(n)` | Unicode variable-length string (for multilingual data) | '你好'                          |
# | `NCHAR(n)`    | Unicode fixed-length string                            | 'पाठ'                         |
#
# ### Synatx :
#     CREATE TABLE students (
#     name VARCHAR(50),
#     city CHAR(10)
#     );

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# <br><br>

# %% [markdown]
# ## 3. Date and Time Data Types
#
# | Data Type   | Description                               | Example               |
# | ----------- | ----------------------------------------- | --------------------- |
# | `DATE`      | Stores only date (YYYY-MM-DD)             | `2025-10-16`          |
# | `TIME`      | Stores only time (HH:MM:SS)               | `13:45:30`            |
# | `DATETIME`  | Stores both date and time                 | `2025-10-16 13:45:30` |
# | `TIMESTAMP` | Stores date & time with automatic updates | `2025-10-16 13:45:30` |
# | `YEAR`      | Stores year (2 or 4 digits)               | `2025`                |
#
#
# ### Syntax :
#
#     CREATE TABLE orders (
#     order_id INT,
#     order_date DATE,
#     delivery_time TIME,
#     created_at DATETIME
#     );

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# <br><br>

# %% [markdown]
# ## 4. Binary Data Types
#
# | Data Type      | Description                               | Example         |
# | -------------- | ----------------------------------------- | --------------- |
# | `BINARY(n)`    | Fixed-length binary data                  | 101010          |
# | `VARBINARY(n)` | Variable-length binary data               | 0101            |
# | `BLOB`         | Large binary object (Binary Large Object) | image file, PDF |
#
#
# ### Syntax :
#     CREATE TABLE files (
#     file_id INT,
#     file_data BLOB
#     );

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# <br><br>

# %% [markdown]
# ## 5. JSON
#
# - JSON (JavaScript Object Notation) is a data type in MySQL used to store structured data such as:
#
# - key–value pairs
#
# - arrays
#
# - nested objects
#
# - lists
#
# - It behaves like a mini-database inside a single column.
#
# - MySQL introduced JSON data type in MySQL 5.7+.
#
#
#
#
# ### Syntax :
#     CREATE TABLE users (
#     id INT,
#     preferences JSON
#     );

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
#
# <br><br>

# %% [markdown]
# ----
# # 🧩 SQL Operators
# - SQL Operators are special symbols or keywords used to perform operations on data —
# such as comparison, arithmetic, logical tests, and pattern matching
#
# ## Types of SQL Operators
#
# | Category                    | Description                               |
# | --------------------------- | ----------------------------------------- |
# | **1. Arithmetic Operators** | Perform mathematical operations           |
# | **2. Comparison Operators** | Compare two values                        |
# | **3. Logical Operators**    | Combine multiple conditions               |
# | **4. Bitwise Operators**    | Perform bit-level operations (rare)       |
# | **5. Special Operators**    | Used for patterns, ranges, or null checks |

# %% [markdown]
# ## 1️⃣ Arithmetic Operators
#
# | Operator | Description         | Example          | Result |
# | -------- | ------------------- | ---------------- | ------ |
# | `+`      | Addition            | `SELECT 10 + 5;` | 15     |
# | `-`      | Subtraction         | `SELECT 10 - 5;` | 5      |
# | `*`      | Multiplication      | `SELECT 10 * 5;` | 50     |
# | `/`      | Division            | `SELECT 10 / 5;` | 2      |
# | `%`      | Modulus (remainder) | `SELECT 10 % 3;` | 1      |
#
#
# <br>
# <br>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# <br>
# <br>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# <br>
# <br>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# <br>
# <br>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# <br>
# <br>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# <br>
# <br>

# %% [markdown]
# ## 2️⃣ Comparison Operators
#
# | Operator     | Description              | Example                      |
# | ------------ | ------------------------ | ---------------------------- |
# | `=`          | Equal to                 | `WHERE city = 'Delhi'`       |
# | `!=` or `<>` | Not equal to             | `WHERE city <> 'Mumbai'`     |
# | `>`          | Greater than             | `WHERE age > 25`             |
# | `<`          | Less than                | `WHERE salary < 50000`       |
# | `>=`         | Greater than or equal to | `WHERE marks >= 40`          |
# | `<=`         | Less than or equal to    | `WHERE date <= '2025-10-16'` |
#
#
# <br>
# <br>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# <br>
# <br>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# <br>
# <br>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# <br>
# <br>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# <br>
# <br>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# <br>
# <br>

# %% [markdown]
# ## 3️⃣ Logical Operators
#
#
# | Operator | Description                              | Example                                   |
# | -------- | ---------------------------------------- | ----------------------------------------- |
# | `AND`    | Returns TRUE if both conditions are TRUE | `WHERE age > 18 AND city = 'Delhi'`       |
# | `OR`     | Returns TRUE if any condition is TRUE    | `WHERE city = 'Delhi' OR city = 'Mumbai'` |
# | `NOT`    | Reverses condition result                | `WHERE NOT city = 'Delhi'`                |

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
#
# <br>
# <br>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# <br>
# <br>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
#
# <br>
# <br>

# %% [markdown]
# ## 4️⃣ Bitwise Operators (rarely used)
#
# | Operator | Description | Example             |           |         |
# | -------- | ----------- | ------------------- | --------- | ------- |
# | `&`      | Bitwise AND | `SELECT 5 & 3;` → 1
# |           |         |
# |       | Bitwise OR          | `SELECT 5 3;` → 7 |
# | `^`      | Bitwise XOR | `SELECT 5 ^ 3;` → 6 |           |         |

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# <br>
# <br>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# <br>
# <br>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# <br>
# <br>

# %% [markdown]
# ## 5️⃣ Special Operators
#
# | Operator      | Description                         | Example                                           |
# | ------------- | ----------------------------------- | ------------------------------------------------- |
# | `BETWEEN`     | Checks if value lies within a range | `WHERE salary BETWEEN 30000 AND 50000`            |
# | `IN`          | Matches a list of values            | `WHERE city IN ('Delhi','Mumbai','Pune')`         |
# | `IS NULL`     | Checks for NULL values              | `WHERE email IS NULL`                             |
# | `IS NOT NULL` | Checks for non-NULL values          | `WHERE phone IS NOT NULL`                         |
# | `EXISTS`      | Checks if subquery returns any row  | `WHERE EXISTS (SELECT * FROM orders)`             |
# | `ANY`         | Compares with any value in a list   | `WHERE salary > ANY (SELECT salary FROM interns)` |
# | `ALL`         | Compares with all values in a list  | `WHERE salary > ALL (SELECT salary FROM interns)` |
# | `LIKE`        | Matches a pattern using wildcards   | `WHERE name LIKE 'M%'`                            |
#
#
#
# <br>

# %% [markdown]
# <br>
# <br>
#
# ![image.png](data:image/png;base64,...)
#
# <br>
# <br>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
#
# <br>
# <br>

# %% [markdown]
# ## 6️⃣ Wildcard Operators (used with LIKE)
#
# ### **LIKE**
#
# - It is filter the records from the column based on the pattern specified in the sql query.
# - Like is used in the where clause with the following statement
#
#     - SELECT
#     - UPDATE
#     - DELETE
#
#
#
# <br>
#
# ## Conjunction that is used with Like Operator.
#
#
#
#
# | Wildcard | Meaning                              | Example                          |
# | -------- | ------------------------------------ | -------------------------------- |
# | `%`      | Zero or more characters              | `'A%'` → Starts with A           |
# | `_`      | Exactly one character                | `'S_m'` → “Sam”, “Sim”           |
# | `[ ]`    | Any single character inside brackets | `'[AB]%'` → Starts with A or B   |
# | `[^ ]`   | Excludes characters inside brackets  | `'[^A]%'` → Doesn’t start with A |
#
#
#
# <br>
# <br>
#
# ## 1. Percentage %
#  - It represent zero ,one ,multiple ,character. But % length is not fixed.
#
# <br>
#
# | Pattern      | Meaning                               | Example Match             |
# | ------------ | ------------------------------------- | ------------------------- |
# | `LIKE '%a%'` | **‘a’ is anywhere** in the string     | `data`, `apple`, `banana` |
# | `LIKE '%a'`  | **‘a’ is at the end**                 | `india`, `panda`          |
# | `LIKE 'a%'`  | **‘a’ is at the start**               | `apple`, `animal`         |
# | `LIKE 'a%b'` | **Starts with ‘a’ and ends with ‘b’** | `acb`, `a123b`, `ab`      |
#
#
# <br>
# <br>
#
#
# ![image.png](data:image/png;base64,...)
#
# <br>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# <br>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# <br>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# <br>

# %% [markdown]
# ## 2. Underscore _
#
# - It represent zero ,one ,multiple ,character, have a fixed length.
# <br>
#
# | Pattern       | Meaning                                                            | Example Matches         |
# | ------------- | ------------------------------------------------------------------ | ----------------------- |
# | `LIKE '____'` | String has **exactly 4 characters**                                | `data`, `mohit`, `abcd` |
# | `LIKE '_a%'`  | One character **before ‘a’**, anything after                       | `raju`, `mahi`, `ta`    |
# | `LIKE '%a_'`  | Any number of characters **before ‘a’**, and **exactly one after** | `cat`, `data`, `panda`  |
# | `LIKE '_%ab'` | One character at start, **anything between**, ends with **‘ab’**   | `kab`, `tab`, `xcab`    |
#
#
#
#
#
#
# <br>
# <br>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# <br>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# <br>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# <br>

# %% [markdown]
# ## 3. Square Brackets [ ]
#
# - It is used to match any single character from a set (or range) of characters.
#
# - It matches only one position in the string.
#
# <br>
#
# | Pattern    | Meaning                    | Example Matches        |
# | ---------- | -------------------------- | ---------------------- |
# | `'[AB]%'`  | Starts with **A or B**     | `Apple`, `Banana`      |
# | `'[xyz]%'` | Starts with **x, y, or z** | `yellow`, `xenon`      |
# | `'[A-C]%'` | Starts with **A, B, or C** | `Cat`, `Ball`, `Apple` |
#
#
#
# <br>
# <br>

# %% [markdown]
# ## 3. Caret Inside Brackets [^ ]
#
# - [^ ] is used to exclude characters inside the brackets.
#
# - It matches any single character not listed inside the brackets.
#
# <br>
#
# | Pattern     | Meaning                        | Example Matches          |
# | ----------- | ------------------------------ | ------------------------ |
# | `'[^A]%'`   | Doesn’t start with **A**       | `Banana`, `Mango`        |
# | `'[^AB]%'`  | Doesn’t start with **A or B**  | `Cat`, `Dog`, `Elephant` |
# | `'[^0-9]%'` | Doesn’t start with a **digit** | `Hello`, `World`         |
#
#
#
#
#
# <br>
# <br>

# %% [markdown]
# ----
#
# # 🧩 SQL Data Constraints
#
# - Constraints are rules applied to columns in a table to ensure the accuracy and reliability of the data in the database.
# - They help maintain data integrity by preventing invalid or inconsistent data.
#
# ## Types of SQL Constraints
#
# | Constraint                    | Description                                                                 | Example                                           |
# | ----------------------------- | --------------------------------------------------------------------------- | ------------------------------------------------- |
# | **NOT NULL**                  | Ensures that a column cannot have a NULL value.                             | `name VARCHAR(50) NOT NULL`                       |
# | **UNIQUE**                    | Ensures that all values in a column are different (no duplicates).          | `email VARCHAR(100) UNIQUE`                       |
# | **PRIMARY KEY**               | Uniquely identifies each record in a table. Combines **NOT NULL + UNIQUE**. | `id INT PRIMARY KEY`                              |
# | **FOREIGN KEY**               | Links two tables together; ensures referential integrity.                   | `FOREIGN KEY (dept_id) REFERENCES department(id)` |
# | **CHECK**                     | Ensures that all values in a column satisfy a specific condition.           | `age INT CHECK (age >= 18)`                       |
# | **DEFAULT**                   | Provides a default value if no value is specified.                          | `status VARCHAR(10) DEFAULT 'Active'`             |
# | **AUTO_INCREMENT / IDENTITY** | Automatically generates unique numeric values. (MySQL / SQL Server)         | `id INT AUTO_INCREMENT PRIMARY KEY`               |
# | **INDEX**                     | Improves the speed of data retrieval. (Not a constraint, but related)       | `CREATE INDEX idx_name ON employee(name);`        |

# %% [markdown]
# <br>
#
# ## 1️⃣ NOT NULL Constraint
#
# - NULL means "no value" / unknown value, not zero, not empty string.
# - Ensures the column must have a value.
# - Prevents storing NULL.
# - Used for essential fields like email, username, etc.
#
# ####Syntax:
#
#     CREATE TABLE student (
#     id INT,
#     name VARCHAR(50) NOT NULL,
#     age INT
#     );

# %% [markdown]
# <br>
#
#
# ![image.png](data:image/png;base64,...)
# <br><br>

# %% [markdown]
# ## 2️⃣ UNIQUE Constraint
#
# - Ensures that all values in a column are different.
# - No duplicate values allowed.
#
#     CREATE TABLE users (
#     user_id INT PRIMARY KEY,
#     email VARCHAR(100) UNIQUE
#     );

# %% [markdown]
# <br>
#
# ![image.png](data:image/png;base64,...)
#
# <br><br>

# %% [markdown]
# ## 3️⃣ PRIMARY KEY Constraint
#
# - A column or set of columns that uniquely identifies each row in a table.
# - No two rows can have the same primary key value.
#
# <br>
#
# #### Rules of Primary Key
#
# - Uniqueness: Duplicate values ❌
# - Not Null: Cannot be NULL ❌
# - Each table can have only ONE primary key.
# - Primary key can be:
# - Single-column PK
# - Composite PK (two or more columns together)
#
#
# #### Syntax:
#
#     CREATE TABLE employee (
#     emp_id INT PRIMARY KEY,
#     emp_name VARCHAR(50)
#     );

# %% [markdown]
# <br>
#
# ![image.png](data:image/png;base64,...)
#
# <br><br>

# %% [markdown]
# ## 4️⃣ FOREIGN KEY Constraint
#
# - A column in one table that refers to the Primary Key of another table.
# - Used to maintain Referential Integrity between tables.
#
# #### Purpose
#
# - Ensures relationships between tables stay valid.
# - Prevents invalid data insertion (e.g., order with non-existing customer).
#
# #### Syntax:
#     CREATE TABLE orders (
#     order_id INT PRIMARY KEY,
#     user_id INT,
#     FOREIGN KEY (user_id) REFERENCES users(user_id)
#     );

# %% [markdown]
# <br>
#
# ![image.png](data:image/png;base64,...)
#
#
# <br><br>

# %% [markdown]
# ## 6️⃣ DEFAULT Constraint
#
# - Sets a predefined value for a column when no value is provided during INSERT.
# - Ensures the column never stays EMPTY unless specifie
#
# #### Purpose
#
# - Avoids NULL values.
#
# - Provides automatic values (like status, timestamps, counters).
#
# - Makes INSERT queries simpler.
#
#
#
# #### Syntax:
#     CREATE TABLE customer (
#     id INT PRIMARY KEY,
#     name VARCHAR(50),
#     country VARCHAR(30) DEFAULT 'India'
#     );

# %% [markdown]
# <br>
#
# ![image.png](data:image/png;base64,...)
#
# <br><br>

# %% [markdown]
# ## ALTER TABLE — Adding Constraints Later
#
#     ALTER TABLE student
#     ADD CONSTRAINT chk_age CHECK (age >= 18);
#
#     ALTER TABLE users
#     ADD CONSTRAINT fk_user FOREIGN KEY (dept_id) REFERENCES department(id);

# %% [markdown]
# <br>
#
# ![image.png](data:image/png;base64,...)
#
#
# <br><br>

# %% [markdown]
# <br>
#
# # All Constraint in one example
#
# <br>
#
# ![image.png](data:image/png;base64,...)
#
#
# <br><br>
